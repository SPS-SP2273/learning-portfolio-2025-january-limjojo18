# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Exercise 1 (Learning to interrupt)

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 while True:
# ----> 2     print('*', end='')
#
# File /opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py:684, in OutStream.write(self, string)
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
# --> 684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#     688     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Exercise 2 (Resetting & Restarting the Kernal)

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
print('Hello World')
# Out:
# Hello World

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 352 ns ± 3.29 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 387 ns ± 2.35 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# ## Meanings

# %% [markdown]
# ns = nanoseconds
#
# The output shows the average time taken and standard deviation to run a single loop
# The first code takes a shorter time due to less complexity
